# %%
Ebais={ 
    'table1': [],
    'table2': [],
    'table3': [],
    'table4': [],
    'table5': [],
    'table6': [],
  }

Gonzaga={ 
    'table1': [],
    'table2': [],
    'table3': [],
    'table4': [],
    'table5': [],
    'table6': []
  }

Iggys={
    'table1': [],
    'table2': [],
    'table3': [],
    'table4': [],
    'table5': [],
    'table6': [],
    'table7': [],
    'table8': [],
    'table9': [],
    'table10': [],
    'table11': [],
    'table12': []
  }

IRH={
    'table1': [],
    'table2': [],
    'table3': [],
    'table4': [],
    'table5': [],
    'table6': [],
    'table7': [],
    'table8': []
  }

JSEC={
    'table1': [],
    'table2': [],
    'table3': [],
    'table4': [],
    'table5': [],
    'table6': [],
    'table7': [],
    'table8': []
  }

# %%
def look(table,canteen,canteen2):
    #TABLE: TABLE user is occupying
    #CANTEEN: The CANTEEN where user occupied TABLE
    #CANTEEN2: User is asking for available tables in CANTEEN2
    #When user marks their spot in a table
    canteen[table].append('Unavailable')
    print("Current Table Status:")
    print(canteen)
    print()
    
    print("Tables Available")
    #When user asks for available tables
    make_keys=list(canteen2.keys())
    for num in make_keys:
        if canteen2[num]==[]:
            print(num) 
    print()
    #If User inputs that they've left the canteen already; makes it available
    canteen[table].remove('Unavailable') 
    #just printed the dictionary to verify na 'Unavailable' was removed
    print("Current Table Status:")
    print(canteen)
    print()

look('table1',Ebais,IRH)
# Out:
# Current Table Status:
# {'table1': ['Unavailable'], 'table2': [], 'table3': [], 'table4': [], 'table5': [], 'table6': []}
#
# Tables Available
# table1
# table2
# table3
# table4
# table5
# table6
# table7
# table8
#
# Current Table Status:
# {'table1': [], 'table2': [], 'table3': [], 'table4': [], 'table5': [], 'table6': []}
